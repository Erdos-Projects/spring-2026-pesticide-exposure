# %% [markdown]
# ## Research Question
# Do pesticide usage levels (2016-2019) show a statistically significant association with state-level COPD or asthma prevalence?
#
# Goal: Identify candidate pesticides for deeper county-level analysis. To accomplish this we will
# - Load USGS pesticide data
# - Load CDC PLACES data
# - Clean and merge datasets
# - Aggregate to state level
# - Explore correlations
#
# Note: In order to keep this notebook self-contained (and so that I could better understand what's going on), some of the contents overlap with Sunyoung's EDA.

# %%
#import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %% [markdown]
# Now we will load/clean the relevant data.
#
# The first souce we utilize comes from the USGS National Water-Quality Assessment (NAWQA) Project's Pesticide National Synthesis Project. (LINK)
# - Provides county-level agricultural pesticide-use estimates for approximately 400 compounds.
# - Time range: 1992-2019. Consists of tab-separated file (txt) for each year from 1992 to 2012, and additional metadata files (xml) for the 2013-2017 range, 2018 and 2019.
# - The estimate will be NaN if there were not enough data to make an estimate.
#
# The second source we utilize
